# %% [markdown]
# # CTA200 2023 Assignment 3

# %% [markdown]
# Since I have now been assigned my project and am not taking this course for credit, I will begin my project now and submit what I have completed thus far for this assignment.

# %% [markdown]
# ## Question 1
# - For each point in the complex plane $c = x + iy$, with $−2 < x < 2$ and $−2 < y < 2$, set $z_0 = 0$ and iterate the equation $z_{i+1} = z_i^2 + c$. Note what happens to the $z_i$'s: some points will remain bounded in absolute value $|z|^2=\mathcal{R}(z)^2 + \mathcal{J}(z)^2$, while others will run off to infinity. Make an image in which your points $c$ that diverge are given one color and those that stay bounded are given another. Make a second image where the points are coloured by a colourscale that indicates the iteration number at which the given point diverged.
#
# - For this question, put the code that does the iteration in a function and place this function in a separate .py file which you import in your .ipynb. Perform the plots in the notebook.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

num_points = 500
max_itr = 25

re = np.linspace(-2, 2, num_points)
im = np.linspace(-2, 2, num_points)
c = re[np.newaxis, :] + im[:, np.newaxis] * 1j
z = 0
itr = 0
itr_plot = np.zeros(np.shape(c))

for _ in range(max_itr):
    z = z ** 2 + c
    for i in range(len(re)):
        for j in range(len(im)):
            if abs(z[i,j]) >= 100:
                itr_plot[i,j] = itr
    itr+=1

z_plot = (abs(z) <= 2)

fig, ax = plt.subplots(1,2,figsize=(12,12))
ax[0].imshow(z_plot, cmap="binary",extent=(-2,2,-2,2))
#ax[1].imshow(itr_plot,extent=(-2,2,-2,2))
img = ax[1].imshow(itr_plot,extent=(-2,2,-2,2))
divider = make_axes_locatable(ax[1])
cax = divider.append_axes("right", size="5%", pad=0.05)
plt.colorbar(img,cax)

plt.show()
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_3968\431366081.py:16: RuntimeWarning: overflow encountered in square
#   z = z ** 2 + c
# C:\Users\lucas\AppData\Local\Temp\ipykernel_3968\431366081.py:16: RuntimeWarning: invalid value encountered in square
#   z = z ** 2 + c
